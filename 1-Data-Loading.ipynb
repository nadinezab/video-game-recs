# %% [markdown]
# # Obtain data

# %% [markdown]
# The dataset was downloaded from https://cseweb.ucsd.edu/~jmcauley/datasets.html#steam_data file *Version 1: User and Item Data*.

# %%
import pandas as pd
import numpy as np
import json
from demjson import decode
import ast

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_json('../Data/steam/users_items.json')
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-e449a9cb1561> in <module>
# ----> 1 df = pd.read_json('../Data/steam/users_items.json')
#       2 df.head()
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     590         return json_reader
#     591
# --> 592     result = json_reader.read()
#     593     if should_close:
#     594         try:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/json/_json.py in read(self)
#     715             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     716         else:
# --> 717             obj = self._get_object_parser(self.data)
#     718         self.close()
# ...

# %%
openfile = open('../Data/steam/users_items.json')
jsondata = json.load(openfile)
df = pd.DataFrame(jsondata)
openfile.close()

df.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-ff82cd55ef27> in <module>
#       1 openfile = open('../Data/steam/users_items.json')
# ----> 2 jsondata = json.load(openfile)
#       3 df = pd.DataFrame(jsondata)
#       4 openfile.close()
#       5
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
# Created a test file with just one user and 3 games
df = pd.read_json('../Data/steam/test.json')
df.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982480          277  76561197970982480
# 1  76561197970982480          277  76561197970982480
# 2  76561197970982480          277  76561197970982480
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1  http://steamcommunity.com/profiles/76561197970...
# 2  http://steamcommunity.com/profiles/76561197970...
#
#                                                items
# 0  {'item_id': '10', 'item_name': 'Counter-Strike...
# 1  {'item_id': '20', 'item_name': 'Team Fortress ...
# 2  {'item_id': '30', 'item_name': 'Day of Defeat'...

# %%
# attempt using decode
# possible issue with loading file syntax

bad_json = open('../Data/steam/users_items.json')
jsondata = decode(bad_json)
df = pd.DataFrame(jsondata)
openfile.close()

df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/demjson.py in set_text(self, txt, encoding)
#    1674         try:
# -> 1675             decoded = helpers.unicode_decode( txt, encoding )
#    1676         except JSONError:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/demjson.py in unicode_decode(txt, encoding)
#    1241             if encoding is None or encoding == 'auto':
# -> 1242                 encoding = helpers.auto_detect_encoding( txt )
#    1243
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/demjson.py in auto_detect_encoding(s)
#    1146         """
# -> 1147         if not s or len(s)==0:
#    1148             return "utf-8"
#
# TypeError: object of type '_io.TextIOWrapper' has no len()
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# test 
# https://stackoverflow.com/questions/4162642/single-vs-double-quotes-in-json
# need to find way to load json file to use this

line = str({'abc':'008565','name':'xyz','description':'can control TV\'s and more'})
print(json.dumps(ast.literal_eval(line)))
# Out:
# {"abc": "008565", "name": "xyz", "description": "can control TV's and more"}

# %%
j = ast.literal_eval(line)
print(j)
# Out:
# {'abc': '008565', 'name': 'xyz', 'description': "can control TV's and more"}

# %%
f = open('../Data/steam/usersitemsdata.json')
file = f.read()
openfile.close()

# %%
file

# %%
file = str(file)

# %%
df = pd.DataFrame.from_dict(file)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-23-5bceb6538401> in <module>
# ----> 1 df = pd.DataFrame.from_dict(file)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in from_dict(cls, data, orient, dtype, columns)
#    1188             raise ValueError("only recognize index or columns for orient")
#    1189
# -> 1190         return cls(data, index=index, columns=columns, dtype=dtype)
#    1191
#    1192     def to_numpy(self, dtype=None, copy=False):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     467         else:
#     468             try:
# --> 469                 arr = np.array(data, dtype=dtype, copy=copy)
#     470             except (ValueError, TypeError) as e:
#     471                 exc = TypeError(
#
# MemoryError:

# %%
df = pd.read_csv('../Data/steam/steam-200k.csv')
df.head()
# Out:
#    151603712  The Elder Scrolls V Skyrim  purchase    1.0  0
# 0  151603712  The Elder Scrolls V Skyrim      play  273.0  0
# 1  151603712                   Fallout 4  purchase    1.0  0
# 2  151603712                   Fallout 4      play   87.0  0
# 3  151603712                       Spore  purchase    1.0  0
# 4  151603712                       Spore      play   14.9  0

# %%
f = open('../Data/steam/usersitemsdata.json')
file = f.read()

# %%
type(file)
# Out:
# str

# %%
j = ast.literal_eval(file)
# Out:
# Traceback (most recent call last):
#
#   File "/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-27-36c39d91473e>", line 1, in <module>
#     j = ast.literal_eval(file)
#
#   File "/opt/anaconda3/envs/learn-env/lib/python3.6/ast.py", line 48, in literal_eval
#     node_or_string = parse(node_or_string, mode='eval')
#
#   File "/opt/anaconda3/envs/learn-env/lib/python3.6/ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 2
# ...

# %%
with open('../Data/steam/usersitemsdata.json') as f:
    lines = f.readlines()

# %%
lines[0]
# Out:
# '{\'user_id\': \'76561197970982479\', \'items_count\': 277, \'steam_id\': \'76561197970982479\', \'user_url\': \'http://steamcommunity.com/profiles/76561197970982479\', \'items\': [{\'item_id\': \'10\', \'item_name\': \'Counter-Strike\', \'playtime_forever\': 6, \'playtime_2weeks\': 0}, {\'item_id\': \'20\', \'item_name\': \'Team Fortress Classic\', \'playtime_forever\': 0, \'playtime_2weeks\': 0}, {\'item_id\': \'30\', \'item_name\': \'Day of Defeat\', \'playtime_forever\': 7, \'playtime_2weeks\': 0}, {\'item_id\': \'40\', \'item_name\': \'Deathmatch Classic\', \'playtime_forever\': 0, \'playtime_2weeks\': 0}, {\'item_id\': \'50\', \'item_name\': \'Half-Life: Opposing Force\', \'playtime_forever\': 0, \'playtime_2weeks\': 0}, {\'item_id\': \'60\', \'item_name\': \'Ricochet\', \'playtime_forever\': 0, \'playtime_2weeks\': 0}, {\'item_id\': \'70\', \'item_name\': \'Half-Life\', \'playtime_forever\': 0, \'playtime_2weeks\': 0}, {\'item_id\': \'130\', \'item_name\': \'Half-Life: Blue Sh
# ...

# %%
len(lines)
# Out:
# 88310

# %%
j = ast.literal_eval(lines[0])

# %%
j
# Out:
# {'user_id': '76561197970982479',
#  'items_count': 277,
#  'steam_id': '76561197970982479',
#  'user_url': 'http://steamcommunity.com/profiles/76561197970982479',
#  'items': [{'item_id': '10',
#    'item_name': 'Counter-Strike',
#    'playtime_forever': 6,
#    'playtime_2weeks': 0},
#   {'item_id': '20',
#    'item_name': 'Team Fortress Classic',
#    'playtime_forever': 0,
#    'playtime_2weeks': 0},
#   {'item_id': '30',
#    'item_name': 'Day of Defeat',
#    'playtime_forever': 7,
#    'playtime_2weeks': 0},
#   {'item_id': '40',
#    'item_name': 'Deathmatch Classic',
#    'playtime_forever': 0,
#    'playtime_2weeks': 0},
#   {'item_id': '50',
#    'item_name': 'Half-Life: Opposing Force',
#    'playtime_forever': 0,
#    'playtime_2weeks': 0},
#   {'item_id': '60',
#    'item_name': 'Ricochet',
#    'playtime_forever': 0,
#    'playtime_2weeks': 0},
#   {'item_id': '70',
#    'item_name': 'Half-Life',
#    'playtime_forever': 0,
#    'playtime_2weeks': 0},
# ...

# %%
newstring = '[' + ','.join(lines) + ']'

# %%
j = ast.literal_eval(newstring)

# %%
len(j)
# Out:
# 88310

# %%
df = pd.read_
